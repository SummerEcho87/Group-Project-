# %%
library("dplyr")
library("rcompanion")
library("car")
library("IDPmisc")
install.packages("caret")
install.packages("gvlma")
install.packages("predictmeans")
install.packages("e1071")
install.packages("lmtest")
library("caret")
library("gvlma")
library("predictmeans")
library("e1071")
library("lmtest")
install.packages("ggplot2")
install.packages("gapminder")
library(gapminder)
# Out:
# The downloaded binary packages are in
# 	/var/folders/4j/cbdp1h515tj4s837d07xrzch0000gn/T//RtmpNliIn6/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/4j/cbdp1h515tj4s837d07xrzch0000gn/T//RtmpNliIn6/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/4j/cbdp1h515tj4s837d07xrzch0000gn/T//RtmpNliIn6/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/4j/cbdp1h515tj4s837d07xrzch0000gn/T//RtmpNliIn6/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/4j/cbdp1h515tj4s837d07xrzch0000gn/T//RtmpNliIn6/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/4j/cbdp1h515tj4s837d07xrzch0000gn/T//RtmpNliIn6/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/4j/cbdp1h515tj4s837d07xrzch0000gn/T//RtmpNliIn6/downloaded_packages

# %%
HBOtitles1 = read.csv("/Users/caitlinbailey/Downloads/archive(2)/HBOtitles1.csv")

# %%
HBOtitles1
# Out:
#      id        title                                        type
# 1    ts300399  Five Came Back: The Reference Films          SHOW
# 2    tm84618   Taxi Driver                                  MOVIE
# 3    tm154986  Deliverance                                  MOVIE
# 4    tm127384  Monty Python and the Holy Grail              MOVIE
# 5    tm120801  The Dirty Dozen                              MOVIE
# 6    ts22164   Monty Python's Flying Circus                 SHOW
# 7    tm70993   Life of Brian                                MOVIE
# 8    tm14873   Dirty Harry                                  MOVIE
# 9    tm119281  Bonnie and Clyde                             MOVIE
# 10   tm98978   The Blue Lagoon                              MOVIE
# 11   tm44204   The Guns of Navarone                         MOVIE
# 12   tm67378   The Professionals                            MOVIE
# 13   tm69997   Richard Pryor: Live in Concert               MOVIE
# ...

# %%
HBOtitles1SHOW <- (HBOtitles1 %>% filter(type %in% c('SHOW')))

# %%
write.csv(HBOtitles1SHOW,"/Users/caitlinbailey/Downloads/archive(2)/HBOtitles1.csv", row.names = FALSE)

# %%
HBOtitles1SHOW
# Out:
#      id       title                                         type
# 1    ts300399 Five Came Back: The Reference Films           SHOW
# 2    ts22164  Monty Python's Flying Circus                  SHOW
# 3    ts45948  Monty Python's Fliegender Zirkus              SHOW
# 4    ts20681  Seinfeld                                      SHOW
# 5    ts22082  Knight Rider                                  SHOW
# 6    ts21715  Thomas & Friends                              SHOW
# 7    ts20678  Saved by the Bell                             SHOW
# 8    ts25028  Wheel of Fortune                              SHOW
# 9    ts23753  Major Dad                                     SHOW
# 10   ts987    Danger Mouse                                  SHOW
# 11   ts2760   Fireman Sam                                   SHOW
# 12   ts63001  High Risk                                     SHOW
# 13   ts20981  Survivor                                      SHOW
# ...

# %%
HBOtitles1MOVIE <- (HBOtitles1 %>% filter(type %in% c('MOVIE')))

# %%
write.csv(HBOtitles1MOVIE,"/Users/caitlinbailey/Downloads/archive(2)/HBOtitles1.csv", row.names = FALSE)

# %%
HBOtitles1MOVIE
# Out:
#      id        title                                     type
# 1    tm84618   Taxi Driver                               MOVIE
# 2    tm154986  Deliverance                               MOVIE
# 3    tm127384  Monty Python and the Holy Grail           MOVIE
# 4    tm120801  The Dirty Dozen                           MOVIE
# 5    tm70993   Life of Brian                             MOVIE
# 6    tm14873   Dirty Harry                               MOVIE
# 7    tm119281  Bonnie and Clyde                          MOVIE
# 8    tm98978   The Blue Lagoon                           MOVIE
# 9    tm44204   The Guns of Navarone                      MOVIE
# 10   tm67378   The Professionals                         MOVIE
# 11   tm69997   Richard Pryor: Live in Concert            MOVIE
# 12   tm16479   White Christmas                           MOVIE
# 13   tm135083  Cairo Station                             MOVIE
# 14   tm89386   Hitler: A Career                          MOVIE
# ...

# %%
#3 differentMOVIE data frames for 3 different decades

# %%
HBOtitlesMOVIE90 <- (HBOtitles1 %>% filter(release_year %in% c('1990','1991','1992','1993','1994','1995','1996','1997','1998','1999')))

# %%
unique(HBOtitlesMOVIE90$type)
# Out:
# [1] "MOVIE" "SHOW"

# %%
HBOtitlesSHOW90 <- (HBOtitles1 %>% filter(release_year %in% c('1990','1991','1992','1993','1994','1995','1996','1997','1998','1999')))

# %%
unique(HBOtitlesSHOW90$type)
# Out:
# [1] "MOVIE" "SHOW"

# %%
HBOtitlesMOVIE10 <- (HBOtitles1 %>% filter(release_year %in% c('2000','2001','2002','2003','2004','2005','2006','2007','2008','2009')))

# %%
unique(HBOtitlesMOVIE10$type)
# Out:
# [1] "SHOW"  "MOVIE"

# %%
HBOtitlesSHOW10 <- (HBOtitles1 %>% filter(release_year %in% c('2000','2001','2002','2003','2004','2005','2006','2007','2008','2009')))

# %%
unique(HBOtitlesSHOW10$type)
# Out:
# [1] "SHOW"  "MOVIE"

# %%
HBOtitlesMOVIE00 <- (HBOtitles1 %>% filter(release_year %in% c('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019')))

# %%
unique(HBOtitlesMOVIE00$type)
# Out:
# [1] "SHOW"  "MOVIE"

# %%
HBOtitlesSHOW00 <- (HBOtitles1 %>% filter(release_year %in% c('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019')))

# %%
unique(HBOtitlesSHOW00$type)
# Out:
# [1] "SHOW"  "MOVIE"

# %% [markdown]
# # How have MOVIE runtimes changed over the decades?

# %%
#90's MOVIE Runtimes

# %%
MeansRunTimeMOVIE90 <- HBOtitles90 %>% group_by(release_year) %>% summarize(Mean = mean(runtime))

# %%
MeansRunTimeMOVIE90
# Out:
#    release_year Mean
# 1  1990         119.28571
# 2  1991          79.84615
# 3  1992          70.66667
# 4  1993         105.57143
# 5  1994         102.12500
# 6  1995         105.80000
# 7  1996          82.14286
# 8  1997         110.06250
# 9  1998          93.09091
# 10 1999          99.15385

# %%
# 90's OVERALL Means Run Time

# %%
TotalMeansRunTime90 <- HBOtitlesMOVIE90 %>% summarize(Mean = mean(runtime))

# %%
TotalMeansRunTime90
# Out:
#   Mean
# 1 98.57851

# %%
#2000's MOVIE Runtimes

# %%
MeansRunTimeMOVIE00 <- HBOtitles00 %>% group_by(release_year) %>% summarize(Mean = mean(runtime))
MeansRunTimeMOVIE00
# Out:
#    release_year Mean
# 1  2000          82.63636
# 2  2001          97.90000
# 3  2002          80.00000
# 4  2003          88.12903
# 5  2004         101.05263
# 6  2005          92.53125
# 7  2006          94.51111
# 8  2007          94.14583
# 9  2008          91.22222
# 10 2009          91.00000

# %%
#2000's Overall Mean Run Time

# %%
TotalMeansRunTime00 <- HBOtitles00 %>% summarize(Mean = mean(runtime))
TotalMeansRunTime00
# Out:
#   Mean
# 1 92.271

# %%
#2010's MOVIE Runtimes

# %%
MeansRunTimeMOVIE10 <- HBOtitles10 %>% group_by(release_year) %>% summarize(Mean = mean(runtime))
MeansRunTimeMOVIE10
# Out:
#    release_year Mean
# 1  2010         86.66667
# 2  2011         84.53488
# 3  2012         87.86916
# 4  2013         84.90370
# 5  2014         82.56209
# 6  2015         74.39462
# 7  2016         73.77072
# 8  2017         76.96270
# 9  2018         73.83959
# 10 2019         74.03589

# %%
#2010's Overall Means Run Time

# %%
TotalMeansRunTime10 <- HBOtitles10 %>% summarize(Mean = mean(runtime))
TotalMeansRunTime10
# Out:
#   Mean
# 1 76.29631

# %% [markdown]
# # How have SHOW runtimes changed over the decades?

# %%
#90's SHOW Runtimes

# %%
HBOtitles1SHOW90 <- (HBOtitles90 %>% filter(type %in% c('SHOW')))

# %%
HBOtitles1SHOW90
# Out:
#    id       title                            type
# 1  ts22176  Stargate SG-1                    SHOW
# 2  ts21223  Pokémon                          SHOW
# 3  ts20339  One Piece                        SHOW
# 4  ts5145   The Challenge                    SHOW
# 5  ts34435  Cowboy Bebop                     SHOW
# 6  ts20983  Neon Genesis Evangelion          SHOW
# 7  ts20960  Power Rangers                    SHOW
# 8  ts25252  Yu-Gi-Oh!                        SHOW
# 9  ts22193  The Magic School Bus             SHOW
# 10 ts22489  Goosebumps                       SHOW
# 11 ts16919  All That                         SHOW
# 12 ts8570   Barney & Friends                 SHOW
# 13 ts27693  Kenan & Kel                      SHOW
# 14 ts251477 My First Errand                  SHOW
# 15 ts22286  Cardcaptor Sakura                SHOW
# 16 ts11397  Adventures of Sonic the Hedgehog SHOW
# 17 ts20918  The Parkers                      SHOW
# 18 ts21693  Sister, Sister                   SHOW
# ...

# %%
TotalMeansRunTimeSHOW90 <- HBOtitlesSHOW90 %>% summarize(Mean = mean(runtime))
TotalMeansRunTimeSHOW90
# Out:
#   Mean
# 1 98.57851

# %%
HBOtitles1SHOW00 <- (HBOtitles00 %>% filter(type %in% c('SHOW')))

# %%
HBOtitles1SHOW00
# Out:
#     id       title                                     type
# 1   ts20981  Survivor                                  SHOW
# 2   ts21567  Gilmore Girls                             SHOW
# 3   ts21034  InuYasha                                  SHOW
# 4   ts21581  Girlfriends                               SHOW
# 5   ts28516  Okupas                                    SHOW
# 6   ts4      Breaking Bad                              SHOW
# 7   ts20371  Top Gear                                  SHOW
# 8   ts21465  Supernatural                              SHOW
# 9   ts12724  30 Rock                                   SHOW
# 10  ts8308   Community                                 SHOW
# 11  ts21469  Grey's Anatomy                            SHOW
# 12  ts17156  Arrested Development                      SHOW
# 13  ts22011  Heartland                                 SHOW
# 14  ts26091  The Staircase                             SHOW
# 15  ts22337  NCIS                                      SHOW
# ...

# %%
TotalMeansRunTime1SHOW00 <- HBOtitles1SHOW00 %>% summarize(Mean = mean(runtime))
TotalMeansRunTime1SHOW00
# Out:
#   Mean
# 1 36.14423

# %%
TotalMeansRunTime1SHOW10 <- HBOtitles1SHOW10 %>% summarize(Mean = mean(runtime))
TotalMeansRunTime1SHOW10
# Out:
#   Mean
# 1 38.67466

# %%
HBOtitles1MOVIE
# Out:
#      id        title                                     type
# 1    tm84618   Taxi Driver                               MOVIE
# 2    tm154986  Deliverance                               MOVIE
# 3    tm127384  Monty Python and the Holy Grail           MOVIE
# 4    tm120801  The Dirty Dozen                           MOVIE
# 5    tm70993   Life of Brian                             MOVIE
# 6    tm14873   Dirty Harry                               MOVIE
# 7    tm119281  Bonnie and Clyde                          MOVIE
# 8    tm98978   The Blue Lagoon                           MOVIE
# 9    tm44204   The Guns of Navarone                      MOVIE
# 10   tm67378   The Professionals                         MOVIE
# 11   tm69997   Richard Pryor: Live in Concert            MOVIE
# 12   tm16479   White Christmas                           MOVIE
# 13   tm135083  Cairo Station                             MOVIE
# 14   tm89386   Hitler: A Career                          MOVIE
# ...

# %%
#How do average popularity ratings compare amongst the popular streaming services? Perform a T-test using the combined data set's averages as mu and your data set's average as the sample mean.

# %%
HBOtitles1Recode = read.csv("/Users/caitlinbailey/Downloads/archive(2) 2/HBOtitlesset.csv")

# %%
HBOtitles1Recode
# Out:
#      id        title                                        type
# 1    ts300399  Five Came Back: The Reference Films          SHOW
# 2    tm84618   Taxi Driver                                  MOVIE
# 3    tm154986  Deliverance                                  MOVIE
# 4    tm127384  Monty Python and the Holy Grail              MOVIE
# 5    tm120801  The Dirty Dozen                              MOVIE
# 6    ts22164   Monty Python's Flying Circus                 SHOW
# 7    tm70993   Life of Brian                                MOVIE
# 8    tm14873   Dirty Harry                                  MOVIE
# 9    tm119281  Bonnie and Clyde                             MOVIE
# 10   tm98978   The Blue Lagoon                              MOVIE
# 11   tm44204   The Guns of Navarone                         MOVIE
# 12   tm67378   The Professionals                            MOVIE
# 13   tm69997   Richard Pryor: Live in Concert               MOVIE
# ...

# %%
unique(HBOtitles1Recode$release_year)
# Out:
#  [1] 1945 1976 1972 1975 1967 1969 1979 1971 1980 1961 1966 1954 1958 1977 1963
# [16] 1956 1960 1973 1974 1959 1978 1989 1990 1987 1984 1983 1982 1986 1981 1988
# [31] 1985 2000 1996 1997 1995 1994 1999 1998 1993 1992 1991 2008 2002 2010 2005
# [46] 2007 2004 2006 2009 2003 2001 2011 2012 2013 2014 2015 2016 2018 2017 2019
# [61] 2020 2022 2021

# %%
HBOtitlesRecode1 <-(HBOtitles1Recode %>% filter(release_year %in% c(1, 2, 3)))

# %%
unique(HBOtitles1Recode$type)
# Out:
# [1] "SHOW"  "MOVIE"

# %%
HBOtitles1RSHOW <- (HBOtitles1Recode %>% filter(type %in% c('SHOW')))

# %%
HBOtitles1RMOVIE <- (HBOtitles1Recode %>% filter(type %in% c('MOVIE')))

# %%
unique(HBOtitles1RMOVIE$type)
# Out:
# [1] "MOVIE"

# %%
unique(HBOtitles1RSHOW$type)
# Out:
# [1] "SHOW"

# %% [markdown]
# # Perform a Kruskall-Wallis Test to test for analysis of variance when non-parametic (in our case uneven sample sizes)

# %% [markdown]
# # Kruskall-Wallis Test for variance of runtime of shows by year

# %%
kruskal.test(runtime ~ release_year, data = HBOtitles1RSHOW)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  runtime by release_year
# Kruskal-Wallis chi-squared = 87.946, df = 41, p-value = 2.845e-05

# %%
kruskal.test(runtime ~ release_year, data = HBOtitles1RMOVIE)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  runtime by release_year
# Kruskal-Wallis chi-squared = 205.51, df = 61, p-value < 2.2e-16

# %%
#P-value shows a significant difference in the average show runtime?

# %%
#Kruskall-Wallis Test for variance of runtime of movies by year?

# %%
#Since this p-value is less than 0.05, we can reject the null hypothesis that the median runtime is the same across the years

# %% [markdown]
# # Have IMDB ratings changed for shows over the decades? If so, how?

# %%
#To start I will run another Kruskal-Wallis test to analyze for variance.

# %%
kruskal.test(imdb_score ~ release_year, data = HBOtitles1RSHOW)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  imdb_score by release_year
# Kruskal-Wallis chi-squared = 157.66, df = 39, p-value = 3.346e-16

# %%
kruskal.test(imdb_score ~ release_year, data = HBOtitles1RMOVIE)
# Out:
# 	Kruskal-Wallis rank sum test
#
# data:  imdb_score by release_year
# Kruskal-Wallis chi-squared = 195, df = 61, p-value = 6.339e-16

# %% [markdown]
# # Our p-value is showing significant at >.05, so we can assume there is a significant difference in scores as the years change?

# %%
mean(HBOtitlesSHOW90$imdb_score, na.rm = TRUE)
# Out:
# [1] 6.864035

# %%
mean(HBOtitlesSHOW00$imdb_score, na.rm = TRUE)
# Out:
# [1] 6.576682

# %%
mean(HBOtitlesSHOW10$imdb_score, na.rm = TRUE)
# Out:
# [1] 6.854203

# %%
mean(HBOtitlesMOVIE90$imdb_score, na.rm = TRUE)
# Out:
# [1] 6.864035

# %%
mean(HBOtitlesMOVIE00$imdb_score, na.rm = TRUE)
# Out:
# [1] 6.576682

# %%
mean(HBOtitlesMOVIE10$imdb_score, na.rm = TRUE)
# Out:
# [1] 6.854203

# %%
IMDB<- HBOtitles1RSHOW %>% group_by(release_year) %>% summarize(Mean = mean(imdb_score, na.rm = TRUE))

# %%
IMDB
# Out:
#    release_year Mean
# 1  1945              NaN
# 2  1969         8.800000
# 3  1972         8.100000
# 4  1981         7.400000
# 5  1982         6.900000
# 6  1983         6.700000
# 7  1984         6.500000
# 8  1987         6.100000
# 9  1988         3.800000
# 10 1989         7.500000
# 11 1991              NaN
# 12 1992         3.800000
# 13 1993         6.350000
# 14 1994         7.325000
# 15 1995         8.050000
# 16 1996         6.800000
# 17 1997         7.900000
# 18 1998         7.880000
# 19 1999         7.666667
# 20 2000         7.940000
# 21 2001         7.516667
# 22 2002         7.975000
# 23 2003         7.177778
# 24 2004         7.000000
# 25 2005         7.020000
# 26 2006         7.966667
# 27 2007         6.930000
# 28 2008         7.435714
# 29 2009         7.252941
# 30 2010         7.216667
# 31 2011         7.162500
# 32 2012         7.567742
# 33 2013         7.062857
# 34 2014         7.282927
# 35 2015         7.338636
# 36 2016         7.277692
# ...

# %%
IMDB2<- HBOtitles1RMOVIE %>% group_by(release_year) %>% summarize(Mean = mean(imdb_score, na.rm = TRUE))

# %%
IMDB2
# Out:
#    release_year Mean
# 1  1954         7.450000
# 2  1956         6.700000
# 3  1958         7.500000
# 4  1959         6.600000
# 5  1960         6.400000
# 6  1961         7.500000
# 7  1963         7.600000
# 8  1966         7.300000
# 9  1967         7.700000
# 10 1969         8.100000
# 11 1971         7.700000
# 12 1972         6.950000
# 13 1973         5.100000
# 14 1974         6.500000
# 15 1975         7.300000
# 16 1976         6.666667
# 17 1977         7.500000
# 18 1978         4.400000
# 19 1979         7.120000
# 20 1980         5.233333
# 21 1981         6.050000
# 22 1982         7.100000
# 23 1983         6.566667
# 24 1984         6.960000
# 25 1985         8.000000
# 26 1986         6.250000
# 27 1987         6.840000
# 28 1988         6.366667
# 29 1989         7.137500
# 30 1990         6.928571
# ⋮  ⋮            ⋮
# 33 1993         7.050000
# 34 1994         6.816667
# 35 1995         6.762500
# 36 1996         6.960000
# 37 1997         6.742857
# ...

# %%
HBOtitles1_MOVIE_mean = mean(HBOtitles1MOVIE$imdb_score, na.rm = TRUE)

# %%
HBOtitles1_MOVIE_mean
# Out:
# [1] 6.246748

# %%
#HBO Movie Average IMDB score is 6.2

# %%
HBOtitles1_SHOW_mean = mean(HBOtitles1SHOW$imdb_score, na.rm = TRUE)

# %%
HBOtitles1_SHOW_mean
# Out:
# [1] 6.977927

# %%
#All Streaming Services Means MOVIE: 6.2 SHOW: 7.0

# %%
#T-TEST for Movies - Is there a significant difference between the average HBO Movie IMDB score and the overall IMDB score for streaming services?

# %%
t_obj <- t.test(HBOtitles1MOVIE$imdb_score, mu = 6.2)
print(t_obj)
# Out:
# 	One Sample t-test
#
# data:  HBOtitles1MOVIE$imdb_score
# t = 2.4279, df = 3428, p-value = 0.01524
# alternative hypothesis: true mean is not equal to 6.2
# 95 percent confidence interval:
#  6.208997 6.284499
# sample estimates:
# mean of x
#  6.246748

# %%
#P-value is less than .05. We can see that HBO Movies have a significantly lower IMDB score at 6.2 than the overall average score

# %%
#T-TEST Shows - Is there a significant difference between the average HBO Show IMDB score and the overall IMDB score for streaming services?

# %%
t_obj <- t.test(HBOtitles1SHOW$imdb_score, mu = 7.0)
print(t_obj)
# Out:
# 	One Sample t-test
#
# data:  HBOtitles1SHOW$imdb_score
# t = -0.90215, df = 1938, p-value = 0.3671
# alternative hypothesis: true mean is not equal to 7
# 95 percent confidence interval:
#  6.929942 7.025912
# sample estimates:
# mean of x
#  6.977927

# %%
#P-value is not greater than .05 so there is a signifcant difference in averages. The Average Netflix score of 7.0 is the same as the overall average of 7.0?
