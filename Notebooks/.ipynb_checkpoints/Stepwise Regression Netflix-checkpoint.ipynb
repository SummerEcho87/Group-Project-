# %%
library("dplyr")
library("rcompanion")
library("car")
library("IDPmisc")

# %%
Netflix = read.csv ("C:/Users/Summe/Documents/GitHub/Group-Project-/Data/Netflix_titles.csv")

# %%
head(Netflix,1)
# Out:
#   id       title                               type
# 1 ts300399 Five Came Back: The Reference Films SHOW
#   description
# 1 This collection includes 12 World War II-era propaganda films â\200” many of which are graphic and offensive â\200” discussed in the docuseries "Five Came Back."
#   release_year age_certification runtime genres            production_countries
# 1 1945         TV-MA             51      ['documentation'] ['US']
#   seasons imdb_id imdb_score imdb_votes tmdb_popularity tmdb_score
# 1 1               NA         NA         0.6             NA

# %%
FitAll = lm(release_year ~ runtime + age_certification + imdb_score + tmdb_score + production_countries + genres + seasons, data = Netflix)

# %%
summary(FitAll)
# Out:
# Call:
# lm(formula = release_year ~ runtime + age_certification + imdb_score +
#     tmdb_score + production_countries + genres + seasons, data = Netflix)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -43.008  -0.204   0.000   0.738  16.565
#
# Coefficients: (24 not defined because of singularities)
#                                                                                                                 Estimate
# (Intercept)                                                                                                    2.026e+03
# runtime                                                                                                       -9.756e-04
# age_certificationTV-14                                                                                        -7.594e-02
# age_certificationTV-G                                                                                         -4.985e-01
# ...

# %%
step(FitAll, direction = 'backward')
# Out:
# Start:  AIC=5416.21
# release_year ~ runtime + age_certification + imdb_score + tmdb_score +
#     production_countries + genres + seasons
#
#                         Df Sum of Sq   RSS    AIC
# - genres               785   14961.0 27945 5272.0
# - runtime                1       0.1 12984 5414.2
# <none>                               12984 5416.2
# - tmdb_score             1      54.0 13038 5421.9
# - age_certification      6     165.3 13149 5427.7
# - imdb_score             1     323.8 13308 5460.0
# - production_countries  81    1602.8 14587 5470.7
# - seasons                1    4288.8 17273 5945.1
#
# Step:  AIC=5271.96
# release_year ~ runtime + age_certification + imdb_score + tmdb_score +
#     production_countries + seasons
#
#                         Df Sum of Sq   RSS    AIC
# - production_countries 105    3021.7 30967 5252.9
# <none>                               27945 5272.0
# - tmdb_score             1     116.8 28062 5277.7
# ...

# %% [markdown]
# Strongest cooreleations: runtime, age_certification, imdb/tmbd_scores and number of seasons.
