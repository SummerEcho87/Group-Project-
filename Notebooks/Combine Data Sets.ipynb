# %%
import pandas as pd
import sagemaker
import boto3
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import seaborn as sns
import s3fs
import csv

# %%
Netflix = pd.read_csv ("C:/Users/Summe/Documents/GitHub/Group-Project-/Data/Netflix_titles.csv")

# %%
Hulu = pd.read_csv ("C:/Users/Summe/Documents/GitHub/Group-Project-/Data/Hulu.csv")

# %%
HBO = pd.read_csv ("C:/Users/Summe/OneDrive/Desktop/HBO.csv")

# %%
Netflix.shape
# Out:
# (5850, 15)

# %%
Hulu.shape
# Out:
# (2398, 15)

# %%
HBO.shape
# Out:
# (3294, 15)

# %%
# Netflix

# %%
Netflix[["imdb_score", "id"]].groupby("imdb_score").count().plot(
    kind="bar", title="Breakdown by imdb_score"
)
plt.xlabel("IMDB Rating")
plt.ylabel("Review Count")
# Out:
# Text(0, 0.5, 'Review Count')

# %%
# Hulu

# %%
Hulu[["imdb_score", "id"]].groupby("imdb_score").count().plot(
    kind="bar", title="Breakdown by imdb_score"
)
plt.xlabel("IMDB Rating")
plt.ylabel("Review Count")
# Out:
# Text(0, 0.5, 'Review Count')

# %%
# HBO

# %%
HBO[["imdb_score", "id"]].groupby("imdb_score").count().plot(
    kind="bar", title="Breakdown by imdb_score"
)
plt.xlabel("IMDB Rating")
plt.ylabel("Review Count")
# Out:
# Text(0, 0.5, 'Review Count')

# %%
# Combine data sets

# %%
Netflix_Hulu_HBO = pd.concat([Netflix, Hulu, HBO], ignore_index=True, sort=False)

# %%
Netflix_Hulu_HBO.head(5)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %%
Netflix_Hulu_HBO.shape
# Out:
# (11542, 15)

# %%
Netflix_Hulu_HBO.to_csv("C:/Users/Summe/Documents/GitHub/Group-Project-/Data/Combine Data Sets.csv", index=False)
