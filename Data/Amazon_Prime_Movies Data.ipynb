# %%
library(ggplot2)

# %%
#Bar Charts

# %%
amazon_prime_movies = read.csv("/Users/caitlinbailey/Downloads/amazon prime movies.csv")

# %%
amazon_prime_movies
# Out:
#      Movie.Name                                   Language  IMDb.Rating
# 1    John Rambo                                   Tamil     7
# 2    American Pie                                 English   7
# 3    Bombshell                                    English   6.8
# 4    Love Birds                                   Tamil     5.1
# 5    Hippi                                        Telugu    5
# 6    Honey Bunny As Super Team X                  Tamil     None
# 7    Ayyaa                                        Tamil     5.7
# 8    Mukhya Mantri                                Bengali   None
# 9    Gandhi Fer Aa Gea                            Punjabi   4.9
# 10   Premada Vayasu                               Kannada   6
# 11   Tum Se Achcha Kaun Hai                       Hindi     4.5
# 12   Swamy                                        Kannada    6
# 13   Ekkees Tareekh Shubh Muhurat                 Hindi     5.7
# 14   Sealers: One Last Hunt                       English   7.7
# ...

# %%
amazon_prime_movies2 <- amazon_prime_movies[1:20, 1:6]

# %%
amazon_prime_movies2
# Out:
#    Movie.Name                      Language IMDb.Rating Running.Time
# 1  John Rambo                      Tamil    7           1 h 26 min
# 2  American Pie                    English  7           1 h 35 min
# 3  Bombshell                       English  6.8         1 h 48 min
# 4  Love Birds                      Tamil    5.1         2 h 40 min
# 5  Hippi                           Telugu   5           2 h 20 min
# 6  Honey Bunny As Super Team X     Tamil    None        49min
# 7  Ayyaa                           Tamil    5.7         2 h 39 min
# 8  Mukhya Mantri                   Bengali  None        1 h 57 min
# 9  Gandhi Fer Aa Gea               Punjabi  4.9         2 h 13 mins
# 10 Premada Vayasu                  Kannada  6           1 h 56 min
# 11 Tum Se Achcha Kaun Hai          Hindi    4.5         2 h 21 min
# 12 Swamy                           Kannada   6          2 h 34 min
# 13 Ekkees Tareekh Shubh Muhurat    Hindi    5.7         1 h 33 min
# ...

# %%
#Testing Out X and #Group Question 1: How have movie times changed over the decades?

# %%
ggplot(data=amazon_prime_movies2, aes(x=Movie.Name))
# Out:
# plot without title

# %%
ggplot(data=amazon_prime_movies2, aes(x=Year.of.Release)) + geom_bar()
# Out:
# plot without title

# %%
ggplot(data=amazon_prime_movies2, aes(x=Maturity.Rating)) + geom_bar()
# Out:
# plot without title

# %%
# Scatter Plots - Show the relationship between two different data sets of data, best when continuous

# %%
#Scatter Plots

# %%
ggplot(data=amazon_prime_movies2, aes(x=Maturity.Rating, y=Movie.Name)) + geom_point()
# Out:
# plot without title

# %%
ggplot(data=amazon_prime_movies2, aes(x=Year.of.Release, y=Running.Time)) + geom_point()
# Out:
# plot without title

# %%
ggplot(data=amazon_prime_movies2, aes(x=Year.of.Release, y=Running.Time)) + geom_point()

# %%
#Group Question 2: What were the most popular genres of each decade?

# %%
#Group Question 3:Have popularity ratings increased or decreased over time?

# %%
ggplot(data=amazon_prime_movies2, aes(x=IMDb.Rating)) + geom_bar()
# Out:
# plot without title

# %%
ggplot(data=amazon_prime_movies2, aes(x=IMDb.Rating, y=Running.Time)) + geom_point()
# Out:
# plot without title

# %%
ggplot(data=amazon_prime_movies2, aes(x=IMDb.Rating, y=Year.of.Release)) + geom_point()
# Out:
# plot without title

# %%
#Line Chart

# %%
#*Submit Tableau Screenshots*

# %%
#Have shows airing times changed throughout the decades?

# %%
#How do streaming ‘originals’ compare in ratings to other movies?
