# %%
library("dplyr")
library("rcompanion")
library("car")
library("IDPmisc")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode

# %%
amazon_prime_movies = read.csv("/Users/caitlinbailey/Downloads/amazon prime movies.csv")

# %%
amazon_prime_movies
# Out:
#      Movie.Name                                   Language  IMDb.Rating
# 1    John Rambo                                   Tamil     7
# 2    American Pie                                 English   7
# 3    Bombshell                                    English   6.8
# 4    Love Birds                                   Tamil     5.1
# 5    Hippi                                        Telugu    5
# 6    Honey Bunny As Super Team X                  Tamil     None
# 7    Ayyaa                                        Tamil     5.7
# 8    Mukhya Mantri                                Bengali   None
# 9    Gandhi Fer Aa Gea                            Punjabi   4.9
# 10   Premada Vayasu                               Kannada   6
# 11   Tum Se Achcha Kaun Hai                       Hindi     4.5
# 12   Swamy                                        Kannada    6
# 13   Ekkees Tareekh Shubh Muhurat                 Hindi     5.7
# 14   Sealers: One Last Hunt                       English   7.7
# ...

# %%
#Examine Data from 1990-2000, 2000-2010, and 2010- today

# %%
unique(amazon_prime_movies$Year.of.Release)
# Out:
#  [1] "2008" "1999" "2019" "1996" "2018" "2005" "2020" "1997" "2002" "2009"
# [11] "2015" "None" "1993" "2014" "2006" "2016" "2010" "2012" "2017" "2004"
# [21] "1978" "2003" "1982" "1991" "1989" "2000" "2013" "1985" "2007" "1994"
# [31] "1979" "1972" "2001" "1988" "1987" "1977" "2011" "1992" "1981" "1958"
# [41] "1986" "1990" "1965" "1984" "1998" "1995" "1963" "1980" "1976" "1971"
# [51] "1973" "1974" "1983" "1970" "1975" "1969" "1960" "2021" "1956" "1962"
# [61] "1967" "1964" "1961" "1952" "1966" "1968" "1957" "1954" "1959"

# %%
amazon_prime_movies90 <- na.omit(amazon_prime_movies %>% filter(Year.of.Release %in% c('1990','1991','1992','1993','1994','1995','1996','1997','1998','1999')))
amazon_prime_movies00 <- na.omit(amazon_prime_movies %>% filter(Year.of.Release %in% c('2000','2001','2002','2003','2004','2005','2006','2007','2008','2009')))
amazon_prime_movies10 <- na.omit(amazon_prime_movies %>% filter(Year.of.Release %in% c('2010','2011','2012','2013','2014','2015','2016','2017','2018','2019')))

# %%
unique( amazon_prime_movies90$Year.of.Release)
# Out:
#  [1] "1999" "1996" "1997" "1993" "1991" "1994" "1992" "1990" "1998" "1995"

# %%
unique( amazon_prime_movies00$Year.of.Release)
# Out:
#  [1] "2008" "2005" "2002" "2009" "2006" "2004" "2003" "2000" "2007" "2001"

# %%
unique( amazon_prime_movies10$Year.of.Release)
# Out:
#  [1] "2019" "2018" "2015" "2014" "2016" "2010" "2012" "2017" "2013" "2011"

# %%
MeansRunTime <- amazon_prime_movies90 %>% group_by(Year.of.Release) %>% summarize(Mean = mean(runtime))
# Out:
# Error in `summarize()`:
# ! Problem while computing `Mean = mean(runtime)`.
# ℹ The error occurred in group 1: Year.of.Release = "1990".
# Caused by error in `mean()`:
# ! object 'runtime' not found
# Traceback:
#
# 1. amazon_prime_movies90 %>% group_by(Year.of.Release) %>% summarize(Mean = mean(runtime))
# 2. summarize(., Mean = mean(runtime))
# 3. summarise.grouped_df(., Mean = mean(runtime))
# 4. summarise_cols(.data, dplyr_quosures(...), caller_env = caller_env())
# 5. withCallingHandlers({
#  .     for (i in seq_along(dots)) {
#  .         context_poke("column", old_current_column)
#  .         quosures <- expand_across(dots[[i]])
#  .         quosures_results <- map(quosures, summarise_eval_one,
#  .             mask = mask)
#  .         for (k in seq_along(quosures)) {
#  .             quo <- quosures[[k]]
#  .             quo_data <- attr(quo, "dplyr:::data")
#  .             quo_result <- quosures_results[[k]]
#  .             if (is.null(quo_result)) {
# ...

# %%
# Out:
# Error in `summarize()`:
# ! Problem while computing `Mean = mean(runtime)`.
# Caused by error in `mean()`:
# ! object 'runtime' not found
# Traceback:
#
# 1. amazon_prime_movies90 %>% summarize(Mean = mean(runtime))
# 2. summarize(., Mean = mean(runtime))
# 3. summarise.data.frame(., Mean = mean(runtime))
# 4. summarise_cols(.data, dplyr_quosures(...), caller_env = caller_env())
# 5. withCallingHandlers({
#  .     for (i in seq_along(dots)) {
#  .         context_poke("column", old_current_column)
#  .         quosures <- expand_across(dots[[i]])
#  .         quosures_results <- map(quosures, summarise_eval_one,
#  .             mask = mask)
#  .         for (k in seq_along(quosures)) {
#  .             quo <- quosures[[k]]
#  .             quo_data <- attr(quo, "dplyr:::data")
#  .             quo_result <- quosures_results[[k]]
#  .             if (is.null(quo_result)) {
#  .                 next
#  .             }
#  .             types_k <- quo_result$types
# ...
